# %%
#where i get the dataset : https://forexsb.com/historical-forex-data, use metatrader (CSV) format, kalo ga salah ya

# %%
pip install mplfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline
import pandas as pd
import mplfinance as mpf

file = 'GBPJPY_H1_updated.csv'
df = pd.read_csv(file)


#splitting date column and drop unnamed column
df[['Date', 'Time']] = df['Date'].str.split(' ', 1, expand=True)

#create a table with new column (Time)
df = df[['Date','Time','Open', 'High', 'Low','Close','Volume']]
df
# Out:
# C:\Users\zanma\AppData\Local\Temp\ipykernel_7420\2504580127.py:10: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[['Date', 'Time']] = df['Date'].str.split(' ', 1, expand=True)
#              Date   Time     Open     High      Low    Close  Volume
# 0      2007-10-04  07:00  236.700  236.780  236.315  236.490   12699
# 1      2007-10-04  08:00  236.490  236.715  236.490  236.650   10661
# 2      2007-10-04  09:00  236.650  237.460  236.575  237.450   16809
# 3      2007-10-04  10:00  237.450  237.500  236.910  236.980   12359
# 4      2007-10-04  11:00  237.000  237.650  237.000  237.135   18324
# ...           ...    ...      ...      ...      ...      ...     ...
# 99995  2023-10-11  03:00  182.868  182.976  182.820  182.927    3521
# 99996  2023-10-11  04:00  182.928  183.012  182.922  182.997    3573
# 99997  2023-10-11  05:00  183.000  183.014  182.944  182.966    3790
# ...

# %%
def visualize01(when):
    certain_date = df[df['Date'] == when]
    certain_date
    
    #get certain time
    start_time = '00:00'
    end_time = '10:00'
    certain_datetime = certain_date[(certain_date['Time'] >= start_time) & (certain_date['Time'] <= end_time)]
    certain_datetime
    
    #candlestick
    certain_datetime['Time'] = pd.to_datetime(certain_datetime['Time'])  # Make sure 'Date' column is in datetime format
    certain_datetime.set_index('Time', inplace=True) # Set the 'Date' column as index
    mpf.plot(certain_datetime, type='candle', style='classic', title=when, ylabel='level') # Create a candlestick chart
    
def visualize02(when):
    certain_date = df[df['Date'] == when]
    certain_date
    
    #get certain time
    start_time = '00:00'
    end_time = '21:00'
    certain_datetime = certain_date[(certain_date['Time'] >= start_time) & (certain_date['Time'] <= end_time)]
    certain_datetime
    
    #candlestick
    certain_datetime['Time'] = pd.to_datetime(certain_datetime['Time'])  # Make sure 'Date' column is in datetime format
    certain_datetime.set_index('Time', inplace=True) # Set the 'Date' column as index
    mpf.plot(certain_datetime, type='candle', style='classic', title=when, ylabel='level') # Create a candlestick chart

# %%
visualize01('2022-05-02')
visualize01('2022-05-09')
visualize01('2022-05-16')
visualize01('2022-05-23')
visualize01('2022-05-30')
visualize01('2022-06-06')
visualize01('2022-06-13')
visualize01('2022-06-20')
visualize01('2022-06-27')
visualize01('2022-07-04')
visualize01('2022-07-11')
visualize01('2022-07-18')
visualize01('2022-07-25')
visualize01('2022-08-01')
visualize01('2022-08-08')
visualize01('2022-08-15')
visualize01('2022-08-22')
visualize01('2022-08-29')
visualize01('2022-09-05')
visualize01('2022-09-12')
visualize01('2022-09-19')
visualize01('2022-09-26')
visualize01('2022-10-03')
visualize01('2022-10-10')
visualize01('2022-10-17')
visualize01('2022-10-24')
visualize01('2022-10-31')
visualize01('2022-11-07')
visualize01('2022-11-14')
visualize01('2022-11-21')
visualize01('2022-11-28')
visualize01('2022-12-05')
visualize01('2022-12-12')
visualize01('2022-12-19')
visualize01('2022-12-26')
visualize01('2023-01-02')
visualize01('2023-01-09')
visualize01('2023-01-16')
visualize01('2023-01-23')
visualize01('2023-01-30')
visualize01('2023-02-06')
visualize01('2023-02-13')
visualize01('2023-02-20')
visualize01('2023-02-27')
visualize01('2023-03-06')
visualize01('2023-03-13')
visualize01('2023-03-20')
visualize01('2023-03-27')
visualize01('2023-04-03')
visualize01('2023-04-10')
visualize01('2023-04-17')
visualize01('2023-04-24')
visualize01('2023-05-01')
visualize01('2023-05-08')
visualize01('2023-05-15')
visualize01('2023-05-22')
visualize01('2023-05-29')
visualize01('2023-06-05')
visualize01('2023-06-12')
visualize01('2023-06-19')
visualize01('2023-06-26')
visualize01('2023-07-03')
visualize01('2023-07-10')
visualize01('2023-07-17')
visualize01('2023-07-24')
visualize01('2023-07-31')
visualize01('2023-08-07')
visualize01('2023-08-14')
visualize01('2023-08-21')
visualize01('2023-08-28')
visualize01('2023-09-04')
visualize01('2023-09-11')
visualize01('2023-09-18')
visualize01('2023-09-25')
visualize01('2023-10-02')
visualize01('2023-10-09')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 visualize01('2022-05-02')
#       2 visualize01('2022-05-09')
#       3 visualize01('2022-05-16')
#
# NameError: name 'visualize01' is not defined
