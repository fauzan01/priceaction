# %%
#where i get the dataset : https://forexsb.com/historical-forex-data, use metatrader (CSV) format, kalo ga salah ya

# %%
pip install mplfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline
import pandas as pd
import mplfinance as mpf
file = 'GBPJPY_H1_updated.csv'
df = pd.read_csv(file)


#splitting date column and drop unnamed column
df[['Date', 'Time']] = df['Date'].str.split(' ', 1, expand=True)

#create a table with new column (Time)
df = df[['Date','Time','Open', 'High', 'Low','Close','Volume']]
df
# Out:
# C:\Users\zanma\AppData\Local\Temp\ipykernel_13356\1551105002.py:9: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[['Date', 'Time']] = df['Date'].str.split(' ', 1, expand=True)
#              Date   Time     Open     High      Low    Close  Volume
# 0      2007-10-04  07:00  236.700  236.780  236.315  236.490   12699
# 1      2007-10-04  08:00  236.490  236.715  236.490  236.650   10661
# 2      2007-10-04  09:00  236.650  237.460  236.575  237.450   16809
# 3      2007-10-04  10:00  237.450  237.500  236.910  236.980   12359
# 4      2007-10-04  11:00  237.000  237.650  237.000  237.135   18324
# ...           ...    ...      ...      ...      ...      ...     ...
# 99995  2023-10-11  03:00  182.868  182.976  182.820  182.927    3521
# 99996  2023-10-11  04:00  182.928  183.012  182.922  182.997    3573
# 99997  2023-10-11  05:00  183.000  183.014  182.944  182.966    3790
# ...

# %%
#start_date = '2023-05-01'
#end_date = '2023-09-10'
#x = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]
#x

#get certain date



def session_visualize(when):
    certain_date = df[df['Date'] == when]
    certain_date
    
    #get certain time
    start_time = '03:00'
    end_time = '11:00'
    certain_datetime = certain_date[(certain_date['Time'] >= start_time) & (certain_date['Time'] <= end_time)]
    certain_datetime
    
    #candlestick
    certain_datetime['Time'] = pd.to_datetime(certain_datetime['Time'])  # Make sure 'Date' column is in datetime format
    certain_datetime.set_index('Time', inplace=True) # Set the 'Date' column as index
    mpf.plot(certain_datetime, type='candle', style='classic', title=when, ylabel='level') # Create a candlestick chart
    
def whole_day_visualize(when):
    certain_date = df[df['Date'] == when]
    certain_date
    
    #get certain time
    start_time = '00:00'
    end_time = '21:00'
    certain_datetime = certain_date[(certain_date['Time'] >= start_time) & (certain_date['Time'] <= end_time)]
    certain_datetime
    
    #candlestick
    certain_datetime['Time'] = pd.to_datetime(certain_datetime['Time'])  # Make sure 'Date' column is in datetime format
    certain_datetime.set_index('Time', inplace=True) # Set the 'Date' column as index
    mpf.plot(certain_datetime, type='candle', style='classic', title=when, ylabel='level') # Create a candlestick chart

# %%
session_visualize('2022-05-04')
session_visualize('2022-05-11')
session_visualize('2022-05-18')
session_visualize('2022-05-25')
session_visualize('2022-06-01')
session_visualize('2022-06-08')
session_visualize('2022-06-15')
session_visualize('2022-06-22')
session_visualize('2022-06-29')
session_visualize('2022-07-06')
session_visualize('2022-07-13')
session_visualize('2022-07-20')
session_visualize('2022-07-27')
session_visualize('2022-08-03')
session_visualize('2022-08-10')
session_visualize('2022-08-17')
session_visualize('2022-08-24')
session_visualize('2022-08-31')
session_visualize('2022-09-07')
session_visualize('2022-09-14')
session_visualize('2022-09-21')
session_visualize('2022-09-28')
session_visualize('2022-10-05')
session_visualize('2022-10-12')
session_visualize('2022-10-19')
session_visualize('2022-10-26')
session_visualize('2022-11-02')
session_visualize('2022-11-09')
session_visualize('2022-11-16')
session_visualize('2022-11-23')
session_visualize('2022-11-30')
session_visualize('2022-12-07')
session_visualize('2022-12-14')
session_visualize('2022-12-21')
session_visualize('2022-12-28')
session_visualize('2023-01-04')
session_visualize('2023-01-11')
session_visualize('2023-01-18')
session_visualize('2023-01-25')
session_visualize('2023-02-01')
session_visualize('2023-02-08')
session_visualize('2023-02-15')
session_visualize('2023-02-22')
session_visualize('2023-03-01')
session_visualize('2023-03-08')
session_visualize('2023-03-15')
session_visualize('2023-03-22')
session_visualize('2023-03-29')
session_visualize('2023-04-05')
session_visualize('2023-04-12')
session_visualize('2023-04-19')
session_visualize('2023-04-26')
session_visualize('2023-05-03')
session_visualize('2023-05-10')
session_visualize('2023-05-17')
session_visualize('2023-05-24')
session_visualize('2023-05-31')
session_visualize('2023-06-07')
session_visualize('2023-06-14')
session_visualize('2023-06-21')
session_visualize('2023-06-28')
session_visualize('2023-07-05')
session_visualize('2023-07-12')
session_visualize('2023-07-19')
session_visualize('2023-07-26')
session_visualize('2023-08-02')
session_visualize('2023-08-09')
session_visualize('2023-08-16')
session_visualize('2023-08-23')
session_visualize('2023-08-30')
session_visualize('2023-09-06')
session_visualize('2023-09-13')
session_visualize('2023-09-20')
session_visualize('2023-09-27')
session_visualize('2023-10-04')
# Out:
# C:\Users\zanma\AppData\Local\Temp\ipykernel_13356\2685427439.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   certain_datetime['Time'] = pd.to_datetime(certain_datetime['Time'])  # Make sure 'Date' column is in datetime format
# C:\Users\zanma\AppData\Local\Temp\ipykernel_13356\2685427439.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   certain_datetime['Time'] = pd.to_datetime(certain_datetime['Time'])  # Make sure 'Date' column is in datetime format
# ...
